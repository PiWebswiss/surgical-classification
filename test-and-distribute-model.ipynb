# %% [markdown]
# # Load model use Python env (only env that has tfjs installed)

# %% [markdown]
# >**env:**
# >1. install python 3.6.8 ``conda create -n ENVNAME python=3.6.8``
# >2. ``pip install tensorflowjs``
# >3. ``conda install notebook`` (conda manage dependencies more effectively than ``pip``)

# %%
import os

# Set the environment variable
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# %%
import tensorflow
# Out:
# WARNING:tensorflow:From c:\Users\louis\anaconda3\envs\tfjs\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import tensorflow as tf
model = tf.keras.models.load_model("model.h5")

model.summary()
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_16 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, 112, 112, 16) 432         input_16[0][0]
# __________________________________________________________________________________________________
# Conv/BatchNorm (BatchNormalizat (None, 112, 112, 16) 64          Conv[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_420 (TFOpL (None, 112, 112, 16) 0           Conv/BatchNorm[0][0]
# __________________________________________________________________________________________________
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\louis\AppData\Local\Programs\Python\Python310\python.exe

# %% [markdown]
# # Git Hub Guide
# https://github.com/tensorflow/tfjs/tree/master/tfjs-converter

# %%
import platform
print(platform.python_version())
print(platform.architecture())
# Out:
# 3.6.8
# ('64bit', 'WindowsPE')

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.15.0'

# %%
! pip show tensorflow-decision-forests
# Out:
# Name: tensorflow-decision-forests
# Version: 1.8.1
# Summary: Collection of training and inference decision forest algorithms.
# Home-page: https://github.com/tensorflow/decision-forests
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\users\louis\anaconda3\envs\tfjs\lib\site-packages
# Requires: absl-py, numpy, pandas, six, tensorflow, wheel, wurlitzer
# Required-by: tensorflowjs

# %%
import tensorflow_decision_forests as tfdf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-48f03801f7af> in <module>
# ----> 1 import tensorflow_decision_forests as tfdf
#
# ModuleNotFoundError: No module named 'tensorflow_decision_forests'

# %%
import os
import tensorflow as tf
import tensorflow_decision_forests as tfdf

print("TensorFlow installation path:", os.path.dirname(tf.__file__))
print("TensorFlow Decision Forests installation path:", os.path.dirname(tfdf.__file__))
# Out:
# WARNING:root:Failure to load the inference.so custom c++ tensorflow ops. This error is likely caused the version of TensorFlow and TensorFlow Decision Forests are not compatible. Full error:c:\Users\louis\anaconda3\envs\tfjs\lib\site-packages\tensorflow_decision_forests\tensorflow\ops\inference\inference.so not found
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 import tensorflow as tf
# ----> 3 import tensorflow_decision_forests as tfdf
#       5 print("TensorFlow installation path:", os.path.dirname(tf.__file__))
#       6 print("TensorFlow Decision Forests installation path:", os.path.dirname(tfdf.__file__))
#
# File c:\Users\louis\anaconda3\envs\tfjs\lib\site-packages\tensorflow_decision_forests\__init__.py:64
#      60 from tensorflow_decision_forests.tensorflow import check_version
# ...

# %%
import sys
sys.path.append('c:\\Users\\louis\\anaconda3\\envs\\tfjs\\lib\\site-packages\\tensorflow_decision_forests\\tensorflow\\ops\\inference\\inference.so')

# %%
import tensorflowjs as tfjs


tfjs.converters.save_keras_model(model, "js-model")
# Out:
# c:\Users\louis\anaconda3\envs\tfjs\lib\site-packages\keras\utils\generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)

# %%
!
